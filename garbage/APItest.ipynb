# %%
print("Hello")
# Out:
# Running cells with 'test (3.12.5) (Python 3.12.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Chirau/Desktop/Python practice accio/Genai/test/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %%
print("Hello")
# Out:
# Hello

# %%
from dotenv import load_dotenv
from google import genai

load_dotenv()

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.7-flash",
    input="Explain how AI works in a few words"
)

print(interaction.output_text)
# Out:
# AI learns patterns from vast amounts of data to make predictions, solve problems, and generate answers.

# %%
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

client = OpenAI()

response = client.responses.create(
    model="gpt-4.1",
    input="Explain how AI works in a few words"
)

print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[6], line 8
#       4 load_dotenv()
#       5
#       6 client = OpenAI()
#       7
# ----> 8 response = client.responses.create(
#       9     model="gpt-4.1",
#      10     input="Explain how AI works in a few words"
#      11 )
#
# File ~\Desktop\Python practice accio\Genai\test\.venv\Lib\site-packages\openai\resources\responses\responses.py:1028, in Responses.create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, moderation, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     987 def create(
#     988     self,
#     989     *,
#    (...)   1026     timeout: float | httpx2.Timeout | None | NotGiven = not_given,
#    1027 ) -> Response | Stream[ResponseStreamEvent]:
# -> 1028     return self._post(
#    1029         "/responses",
#    1030         body=maybe_transform(
#    1031             {
#    1032                 "background": background,
#    1033                 "context_management": context_management,
#    1034                 "conversation": conversation,
#    1035                 "include": include,
#    1036                 "input": input,
#    1037                 "instructions": instructions,
#    1038                 "max_output_tokens": max_output_tokens,
#    1039                 "max_tool_calls": max_tool_calls,
#    1040                 "metadata": metadata,
#    1041                 "model": model,
#    1042                 "moderation": moderation,
#    1043                 "parallel_tool_calls": parallel_tool_calls,
#    1044                 "previous_response_id": previous_response_id,
#    1045                 "prompt": prompt,
#    1046                 "prompt_cache_key": prompt_cache_key,
#    1047                 "prompt_cache_options": prompt_cache_options,
#    1048                 "prompt_cache_retention": prompt_cache_retention,
#    1049                 "reasoning": reasoning,
#    1050                 "safety_identifier": safety_identifier,
#    1051                 "service_tier": service_tier,
#    1052                 "store": store,
#    1053                 "stream": stream,
#    1054                 "stream_options": stream_options,
#    1055                 "temperature": temperature,
#    1056                 "text": text,
#    1057                 "tool_choice": tool_choice,
#    1058                 "tools": tools,
#    1059                 "top_logprobs": top_logprobs,
#    1060                 "top_p": top_p,
#    1061                 "truncation": truncation,
#    1062                 "user": user,
#    1063             },
#    1064             response_create_params.ResponseCreateParamsStreaming
#    1065             if stream
#    1066             else response_create_params.ResponseCreateParamsNonStreaming,
#    1067         ),
#    1068         options=make_request_options(
#    1069             extra_headers=extra_headers,
#    1070             extra_query=extra_query,
#    1071             extra_body=extra_body,
#    1072             timeout=timeout,
#    1073             security={"bearer_auth": True},
#    1074         ),
#    1075         cast_to=Response,
#    1076         stream=stream or False,
#    1077         stream_cls=Stream[ResponseStreamEvent],
#    1078     )
#
# File ~\Desktop\Python practice accio\Genai\test\.venv\Lib\site-packages\openai\_base_client.py:1368, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1359     warnings.warn(
#    1360         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1361         "Please pass raw bytes via the `content` parameter instead.",
#    1362         DeprecationWarning,
#    1363         stacklevel=2,
#    1364     )
#    1365 opts = FinalRequestOptions.construct(
#    1366     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1367 )
# -> 1368 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\Desktop\Python practice accio\Genai\test\.venv\Lib\site-packages\openai\_base_client.py:1141, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1138             err.response.read()
#    1140         log.debug("Re-raising status error")
# -> 1141         raise self._make_status_error_from_response(err.response) from None
#    1143     break
#    1145 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
import os
from dotenv import load_dotenv
from groq import Groq

# Load variables from .env
load_dotenv()

# Create Groq client
client = Groq(api_key=os.getenv("GROQ_API_KEY"))

# Chat completion
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Explain the benefit of low-latency language models."
        }
    ],
    model="openai/gpt-oss-20b",
)

print(chat_completion.choices[0].message.content)
# Out:
# ### Why Low‑Latency Language Models Matter
#
# **Low‑latency** means that a language model can generate a response or make a prediction in a few milliseconds or seconds rather than minutes. In practice this translates into a more natural, “human‑like” interaction for users, and opens up a host of new use‑cases and technical advantages. Below are the main benefits:
#
# | Benefit | What it means | Why it matters |
# |---------|---------------|----------------|
# | **Real‑time conversational AI** | Chatbots, voice assistants, and customer support agents can reply instantly, just like a human. | Users feel more engaged and trust the system more. |
# | **Edge & on‑device inference** | Models run locally on phones, wearables, or embedded boards without a constant internet connection. | Reduces bandwidth costs, protects privacy, and works even in offline or low‑coverage areas. |
# | **Interactive gaming & AR/VR** | NPCs, dynamic story generators, or in‑game dialogue can react instantly to player actions. | Keeps immersion high; lag would break the illusion. |
# | **Fast real‑time translation & transcription** | Multilingual chat or subtitles are generated while a conversation is happening. | Enables global communication without delays. |
# | **Low‑power consumption** | A model that can finish its job quickly uses fewer compute cycles. | Extends battery life on mobile and IoT devices. |
# | **Scalability for large‑scale services** | A single request takes less CPU/GPU time, so more requests can be handled per second. | Higher throughput = cheaper infrastructure, lower operational costs. |
# | **Improved user experience** | Users are less likely to abandon an app or conversation when they don't have to wait. | Directly improves retention and revenue. |
# | **Reduced data usage & cost** | Less back‑and‑forth traffic with the server means cheaper data plans. | Beneficial for regions where data is expensive or limited. |
# | **Better real‑time monitoring & decision support** | Systems that analyze logs, sensor data, or alerts on the fly can take immediate action. | Critical for safety‑critical applications (e.g., autonomous vehicles, industrial control). |
#
# ---
#
# ### Concrete Use Cases
#
# | Domain | Example | Low‑Latency Advantage |
# |--------|---------|------------------------|
# | **Customer support** | AI answering ticket queries in seconds. | Faster resolution times → happier customers. |
# | **Gaming** | NPC dialogue that adapts instantly to player choices. | Maintains narrative flow without hiccups. |
# | **Healthcare** | Real‑time transcription of doctor‑patient conversations. | Improves documentation speed and accuracy. |
# | **Finance** | Instant sentiment analysis of news feeds. | Enables rapid trading decisions. |
# | **Education** | Language tutors providing instant corrections. | Enhances learning efficacy. |
# | **Accessibility** | Live captions for video calls. | Keeps communication seamless for deaf/hard‑of‑hearing users. |
# | **Transportation** | On‑board AI that translates passenger requests in real time. | Enhances service quality in multi‑lingual regions. |
#
# ---
#
# ### Technical Take‑Aways
#
# 1. **Model Architecture** – Smaller transformers, sparse attention, or mixture‑of‑experts can keep compute low while maintaining quality.
# 2. **Hardware Acceleration** – GPUs, TPUs, or specialized ASICs can deliver sub‑second inference.
# 3. **Quantization & Pruning** – Reducing model size (int8/float16) cuts latency dramatically without a huge loss in accuracy.
# 4. **Serverless & Function‑as‑a‑Service** – Deploying on the edge or in containers can reduce round‑trip time.
#
# ---
#
# ### Bottom Line
#
# Low‑latency language models unlock “instant” interactions, enable deployment on a wide array of devices, reduce costs, and broaden accessibility. For any product or service that depends on natural‑language understanding or generation, shaving a few milliseconds off the response time translates directly into better user satisfaction, higher engagement, and new business opportunities.
